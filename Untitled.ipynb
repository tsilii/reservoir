# %% [markdown]
# # Χρονοσειρές Lorentz

# %% [markdown]
# ## 1. Εγκατάσταση βιβλιοθηκών
# #### NumPy → ταχύς χειρισμός πινάκων.
# #### SciPy → έτοιμοι ολοκληρωτές ODE (π.χ. solve_ivp).
# #### Matplotlib → γραφήματα 2-D & 3-D.
# #### pandas → ευέλικτο data container (DataFrame).

# %%
import pandas as pd
import numpy as np
from scipy.integrate import solve_ivp        # εναλλακτικά: from scipy.integrate import odeint
import matplotlib.pyplot as plt
from pyrcn.echo_state_network import ESNRegressor
from numpy import array
import math
import csv

# %% [markdown]
# ## 2. Ορισμός παραμέτρων & εξισώσεων Lorenz
# #### εξισώσεις Lorentz:
# ![image.png](attachment:97d3621f-2c9e-416a-83dd-0885e77f6f85.png)

# %%
# Παράμετροι
sigma = 10.0          # ένταση «περιστροφικού» όρου (σχετικό με Prandtl)
beta  = 8.0 / 3.0     # γεωμετρικός/αγώγιμος συντελεστής
rho   = 28.0          # «θερμική ώθηση» (Rayleigh number)

# 3.2 Συνάρτηση που δίνει τα παράγωγα
def lorenz(t, state):
    """
    t      : τρέχων χρόνος (float, αλλά δεν χρησιμοποιείται ρητά)
    state  : διάνυσμα [x, y, z] τη χρονική στιγμή t
    return : λίστα [dx/dt, dy/dt, dz/dt]
    """
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# %% [markdown]
# ## 3. Ρύθμιση χρονικού πλέγματος & αρχικών συνθηκών

# %%
t0, t_end, dt = 0.0, 500, 0.01       # από 0 ως 50 "δευτερόλεπτα" με βήμα 0.01
t_eval = np.arange(t0, t_end + dt, dt)  # σημείο-σημείο εξαγωγής

initial_state = [1.0, 1.0, 1.0]       # x0, y0, z0

# %% [markdown]
# ## 4. Αριθμητική ολοκλήρωση
# ## H solve_ivp(solve initial value problem) είναι μια συνάρτηση απο το scipy.integrate που επιλύει συστήματα διαφορικών εξισώσεων πρώτης τάξης

# %%
sol = solve_ivp(
    lorenz,                # η συνάρτηση με τα παράγωγα
    (t0, t_end),           # χρονικό διάστημα ολοκλήρωσης
    initial_state,         # αρχικές τιμές
    method="RK45",         # Dormand–Prince 4(5)
    t_eval=t_eval,         # πού θες αποτελέσματα
    rtol=1e-9, atol=1e-12  # έλεγχος σφάλματος
)

# %%
t = sol.t
x, y, z = sol.y          # "ξεδιπλώνουμε" τις τρεις χρονοσειρές

# %% [markdown]
# ## 5. Μετατροπή σε DataFrame

# %%
df = (
    pd.DataFrame({"t": t, "x": x, "y": y, "z": z})
      .set_index("t")        # χρόνος ως index ⇒ έτοιμο για resample/rolling
)
df.head(-1)                    # δείχνει τις 5 πρώτες γραμμές
# Out:
#                x         y          z
# t
# 0.00    1.000000  1.000000   1.000000
# 0.01    1.012566  1.259920   0.984891
# 0.02    1.048821  1.524001   0.973114
# 0.03    1.107206  1.798315   0.965159
# 0.04    1.186865  2.088546   0.961737
# ...          ...       ...        ...
# 499.95  2.303042  1.617246  21.334800
# 499.96  2.244527  1.757772  20.811212
# 499.97  2.205271  1.904950  20.303749
# 499.98  2.184100  2.059340  19.812359
# 499.99  2.180015  2.221698  19.337065
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## 6. Οπτικοποίηση χρονοσειρών

# %%
plt.figure(figsize=(10, 4))
plt.plot(df.index, df["x"], label="x(t)")
plt.plot(df.index, df["y"], label="y(t)")
plt.plot(df.index, df["z"], label="z(t)")
plt.xlabel("t"), plt.legend(), plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ελκυστής («πεταλούδα»)
# ### Δημιουργεί τρισδιάστατο διάγραμμα της τροχιάς του συστήματος Lorenz στον χώρο των μεταβλητών (x, y, z) — δηλαδή οπτικοποιεί το διάσημο “Lorenz attractor”.

# %%
from mpl_toolkits.mplot3d import Axes3D  # μόνο για να ενεργοποιηθεί το 3-D
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(projection="3d")
ax.plot(x, y, z, linewidth=0.5)
ax.set_xlabel("x"), ax.set_ylabel("y"), ax.set_zlabel("z")
plt.tight_layout(); plt.show()

# %% [markdown]
# # Δομή Sliding Window Multi-Step Forecasting
# ## Σκοπός: Δημιουργείς πολλά training samples από τη χρονοσειρά x(t)
# #         Για κάθε sample: Input: 50 τιμές (ιστορικό) , Target: οι επόμενες 800 τιμές
#
#
#
# ### windows: τα παραθυρικά inputs (ιστορικό 50 τιμών)
#
# ### future_windows : τα αντίστοιχα multi-step targets (800 τιμές)
#
# ### prices: η τελευταία τιμή κάθε εισόδου (χρήσιμη αν κάνεις normalization)

# %%
# Εδω πέρα φτιαχνουμε το INput το οποιο μας δινει παραθυρο 50 τιμων στο παρελθον

# Παράδειγμα: df['x'] έχει N=50000 τιμές
values = df['x'].tolist()
window_size = 60

# Φτιάχνουμε παράθυρα που για κάθε i ≥49 παίρνουν
# [values[i], values[i-1], …, values[i-49]]
windows = [
    values[i - window_size + 1 : i + 1][::-1]
    for i in range(window_size - 1, len(values))
]

# %%
values = df['x'].tolist()
input_window   = 60
future_horizon = 140

# Για κάθε i από 0 μέχρι ότου ‘μείνουν’ αρκετές τιμές:
future_windows = [
    # παίρνουμε slice από i+50 (η πρώτη μετά το input) 
    # μέχρι i+50+60 (εκεί που τελειώνει το παράθυρο του μέλλοντος)
    values[i + input_window : i + input_window + future_horizon]
    for i in range(0, len(values) - input_window - future_horizon + 1)
]

# %% [markdown]
# ## Εδώ κάνουμε έναν έλεγχο για να δούμε ότι έχουμε φτιάξει τα παράθυρα  με τις 50 τιμές του παρελθόντος

# %%
df.head(50)
# Out:
#               x          y          z
# t
# 0.00   1.000000   1.000000   1.000000
# 0.01   1.012566   1.259920   0.984891
# 0.02   1.048821   1.524001   0.973114
# 0.03   1.107206   1.798315   0.965159
# 0.04   1.186865   2.088546   0.961737
# 0.05   1.287555   2.400160   0.963806
# 0.06   1.409569   2.738552   0.972608
# 0.07   1.553689   3.109161   0.989731
# 0.08   1.721146   3.517577   1.017187
# 0.09   1.913596   3.969624   1.057512
# 0.10   2.133108   4.471420   1.113899
# 0.11   2.382148   5.029426   1.190354
# 0.12   2.663584   5.650450   1.291894
# 0.13   2.980672   6.341630   1.424787
# 0.14   3.337051   7.110348   1.596844
# 0.15   3.736723   7.964084   1.817757
# 0.16   4.184015   8.910163   2.099504
# 0.17   4.683517   9.955358   2.456795
# 0.18   5.239979  11.105317   2.907560
# 0.19   5.858146  12.363731   3.473435
# 0.20   6.542528  13.731187   4.180197
# 0.21   7.297046  15.203634   5.058030
# 0.22   8.124564  16.770387   6.141469
# 0.23   9.026233  18.411653   7.468798
# 0.24  10.000659  20.095632   9.080554
# 0.25  11.042844  21.775417  11.016773
# 0.26  12.142956  23.386129  13.312536
# 0.27  13.284971  24.843096  15.991501
# 0.28  14.445382  26.042251  19.057419
# 0.29  15.592222  26.864212  22.484245
# 0.30  16.684814  27.183492  26.206460
# 0.31  17.674703  26.883583  30.112351
# 0.32  18.508190  25.877015  34.043822
# 0.33  19.130652  24.127116  37.806132
# 0.34  19.492384  21.665729  41.188907
# 0.35  19.555094  18.600224  43.996037
# 0.36  19.297729  15.104976  46.077767
# 0.37  18.720150  11.397283  47.355866
# 0.38  17.843634   7.703505  47.834028
# 0.39  16.708009   4.225000  47.590712
# 0.40  15.366200   1.113037  46.757843
# 0.41  13.877558  -1.542313  45.493062
# 0.42  12.301454  -3.709692  43.953662
# 0.43  10.692206  -5.404655  42.277709
# 0.44   9.095844  -6.674058  40.574111
# 0.45   7.548659  -7.581103  38.920458
# 0.46   6.077173  -8.193584  37.366039
# 0.47   4.699045  -8.576059  35.937411
# 0.48   3.424451  -8.785533  34.644526
# 0.49   2.257616  -8.869757  33.486244

# %%
windows[0]
# Out:
# [1.2765350458906186,
#  1.2657276448267214,
#  1.2551320911269823,
#  1.2447479583060184,
#  1.2345748700216594,
#  1.2246125001762083,
#  1.2148605729915951,
#  1.2053188638709742,
#  1.1959872006087058,
#  1.1868654634496891,
#  1.177953585239418,
#  1.1692515520246678,
#  1.1607594046846916,
#  1.1524772390269111,
#  1.144405206008938,
#  1.136543512256943,
#  1.1288924219123322,
#  1.1214522568328469,
#  1.1142233968428439,
#  1.1072062803333624,
#  1.1004014062491996,
#  1.0938093343382176,
#  1.0874306854147862,
#  1.0812661422491932,
#  1.075316451565084,
#  1.069582424302753,
#  1.0640649358823648,
#  1.058764927651511,
#  1.053683408636215,
#  1.04882145583042,
#  1.0441802145465247,
#  1.039760900610716,
#  1.0355648015528538,
#  1.0315932769265534,
#  1.0278477591861572,
#  1.0243297562917622,
#  1.021040852251032,
#  1.0179827075363976,
#  1.0151570612204972,
#  1.0125657328030286,
#  1.0102106226085987,
#  1.0080937128561382,
#  1.0062170705701292,
#  1.0045828482772097,
#  1.0031932846123544,
#  1.0020507071282356,
#  1.001157533920638,
#  1.000516274122883,
#  1.0001295301635857,
#  1.0]

# %% [markdown]
# ## Εδώ κάνουμε έναν έλεγχο για να δούμε ότι έχουμε φτιάξει τα παράθυρα  με τις 800 τιμές στο μέλλον

# %%
#΄όπως βλέπουμε η πρώτη τιμή του future window είναι η 50 
df.head(51)
# Out:
#               x          y          z
# t
# 0.00   1.000000   1.000000   1.000000
# 0.01   1.012566   1.259920   0.984891
# 0.02   1.048821   1.524001   0.973114
# 0.03   1.107206   1.798315   0.965159
# 0.04   1.186865   2.088546   0.961737
# 0.05   1.287555   2.400160   0.963806
# 0.06   1.409569   2.738552   0.972608
# 0.07   1.553689   3.109161   0.989731
# 0.08   1.721146   3.517577   1.017187
# 0.09   1.913596   3.969624   1.057512
# 0.10   2.133108   4.471420   1.113899
# 0.11   2.382148   5.029426   1.190354
# 0.12   2.663584   5.650450   1.291894
# 0.13   2.980672   6.341630   1.424787
# 0.14   3.337051   7.110348   1.596844
# 0.15   3.736723   7.964084   1.817757
# 0.16   4.184015   8.910163   2.099504
# 0.17   4.683517   9.955358   2.456795
# 0.18   5.239979  11.105317   2.907560
# 0.19   5.858146  12.363731   3.473435
# 0.20   6.542528  13.731187   4.180197
# 0.21   7.297046  15.203634   5.058030
# 0.22   8.124564  16.770387   6.141469
# 0.23   9.026233  18.411653   7.468798
# 0.24  10.000659  20.095632   9.080554
# 0.25  11.042844  21.775417  11.016773
# 0.26  12.142956  23.386129  13.312536
# 0.27  13.284971  24.843096  15.991501
# 0.28  14.445382  26.042251  19.057419
# 0.29  15.592222  26.864212  22.484245
# 0.30  16.684814  27.183492  26.206460
# 0.31  17.674703  26.883583  30.112351
# 0.32  18.508190  25.877015  34.043822
# 0.33  19.130652  24.127116  37.806132
# 0.34  19.492384  21.665729  41.188907
# 0.35  19.555094  18.600224  43.996037
# 0.36  19.297729  15.104976  46.077767
# 0.37  18.720150  11.397283  47.355866
# 0.38  17.843634   7.703505  47.834028
# 0.39  16.708009   4.225000  47.590712
# 0.40  15.366200   1.113037  46.757843
# 0.41  13.877558  -1.542313  45.493062
# 0.42  12.301454  -3.709692  43.953662
# 0.43  10.692206  -5.404655  42.277709
# 0.44   9.095844  -6.674058  40.574111
# 0.45   7.548659  -7.581103  38.920458
# 0.46   6.077173  -8.193584  37.366039
# 0.47   4.699045  -8.576059  35.937411
# 0.48   3.424451  -8.785533  34.644526
# 0.49   2.257616  -8.869757  33.486244
# 0.50   1.198273  -8.867198  32.454740

# %%
future_windows[0]
# Out:
# [1.2875547703519061,
#  1.2987873425992962,
#  1.3102333352989457,
#  1.321893369221066,
#  1.333768113224454,
#  1.3458582830050403,
#  1.3581646407641936,
#  1.370687995142197,
#  1.3834292011787965,
#  1.3963891598189941,
#  1.4095688170175595,
#  1.4229691636983575,
#  1.4365912356379034,
#  1.4504361135250663,
#  1.464504922147952,
#  1.478798829961528,
#  1.493319049081097,
#  1.5080668351792454,
#  1.5230434875119554,
#  1.5382503481190335,
#  1.5536888016284307,
#  1.569360275246009,
#  1.585266238684408,
#  1.6014082041409403,
#  1.6177877256490358,
#  1.6344063989620379,
#  1.6512658615470006,
#  1.668367792526937,
#  1.6857139126633687,
#  1.703305983860448,
#  1.7211458090674008,
#  1.7392352322776554,
#  1.7575761384810675,
#  1.7761704536525587,
#  1.7950201444136584,
#  1.8141272179272097,
#  1.8334937218973695,
#  1.853121744546441,
#  1.8730134145651014,
#  1.8931709009358175,
#  1.9135964128216147,
#  1.934292199565178,
#  1.9552605506833736,
#  1.9765037957933091,
#  1.998024304501996,
#  2.019824486344175,
#  2.041906790777796,
#  2.0642737071839674,
#  2.0869277648158526,
#  2.109871532633498,
#  2.1331076193115317,
#  2.1566386732507627,
#  2.1804673825781804,
#  2.204596475132446,
#  2.229028718256751,
#  2.253766918738176,
#  2.278813922894868,
#  2.3041726165781404,
#  2.329845925172235,
#  2.3558368134586236,
#  2.382148285328941,
#  2.4087833839248862,
#  2.4357451916666166,
#  2.463036830252747,
#  2.4906614606258057,
#  2.518622282564888,
#  2.5469225346351827,
#  2.575565494291917,
#  2.6045544778754333,
#  2.6338928406111917,
#  2.663583976362054,
#  2.6936313171288786,
#  2.7240383332183544,
#  2.7548085332008987,
#  2.7859454639106174,
#  2.8174527103978524,
#  2.8493338952277103,
#  2.881592678364411,
#  2.914232757135681,
#  2.947257866179774,
#  2.980671777445472,
#  3.0144782998328283,
#  3.0486812782986923,
#  3.0832845940180764,
#  3.118292164078309,
#  3.1537079414725433,
#  3.189535915049585,
#  3.225780108384873,
#  3.2624445795432067,
#  3.299533420708559,
#  3.337050757976484,
#  3.375000751354113,
#  3.4133875942522067,
#  3.4522155119913123,
#  3.4914887619474864,
#  3.5312116327005914,
#  3.571388444000128,
#  3.612023546701525,
#  3.653121320983069,
#  3.694686175993287,
#  3.7367225488709765,
#  3.7792349042549715,
#  3.822227734284144,
#  3.865705557756216,
#  3.909672917884952,
#  3.954134382336822,
#  3.9990945415385277,
#  4.044558008616631,
#  4.090529419236587,
#  4.13701342871474,
#  4.184014711770993,
#  4.231537960383043,
#  4.279587883071311,
#  4.328169204898941,
#  4.377286665633636,
#  4.4269450170936695,
#  4.477149022387676,
#  4.527903453420485,
#  4.579213090876037,
#  4.631082723518307,
#  4.68351714373065,
#  4.73652114751341,
#  4.790099530517865,
#  4.8442570875328315,
#  4.89899861236366,
#  4.954328893222443,
#  5.010252711629531,
#  5.066774838332488,
#  5.123900031405504,
#  5.181633036249393,
#  5.23997858223275,
#  5.298941378525682,
#  5.358526111735509,
#  5.418737441522092,
#  5.479580000583358,
#  5.5410583925018075,
#  5.603177184965171,
#  5.665940908623087,
#  5.729354050396769,
#  5.793421053157918,
#  5.858146314312383,
#  5.923534177382882,
#  5.9895889310263755,
#  6.0563148005816,
#  6.123715947121635,
#  6.19179646643799,
#  6.260560379440864,
#  6.330011630731637,
#  6.400154078690116,
#  6.470991493753989,
#  6.542527557549597,
#  6.614765852157404,
#  6.687709858010349,
#  6.761362942538441,
#  6.835728357766341,
#  6.910809239361275,
#  6.986608594526659,
#  7.063129299261596,
#  7.140374085360607,
#  7.218345537651043,
#  7.297046092673112,
#  7.376478024862643,
#  7.45664344325718,
#  7.537544276650383,
#  7.61918227092281,
#  7.7015589869127785,
#  7.784675784689992,
#  7.868533819576653,
#  7.953134025554222,
#  8.038477113116466,
#  8.124563565622498,
#  8.211393621884287,
#  8.298967270929683,
#  8.38728423428086,
#  8.476343964583933,
#  8.566145639373268,
#  8.656688142916126,
#  8.74797005855996,
#  8.839989651072074,
#  8.932744866039092,
#  9.026233319600689,
#  9.120452281452883,
#  9.21539866297625,
#  9.311069001256689,
#  9.407459458957979,
#  9.50456580859757,
#  9.602383419139885,
#  9.700907237949751,
#  9.800131778041944,
#  9.900051117704185,
#  10.000658879910944,
#  10.101948221781658,
#  10.203911811828311,
#  10.306541819867181,
#  10.409829916215935,
#  10.513767247649795,
#  10.61834442837136,
#  10.723551514747214,
#  10.829377996342867,
#  10.935812795227152,
#  11.042844240494158,
#  11.150460059108141,
#  11.258647350690014,
#  11.367392577194032,
#  11.47668156289166,
#  11.586499473111106,
#  11.696830797931542,
#  11.807659335210474,
#  11.918968173080382,
#  12.030739689948728,
#  12.142955547987313,
#  12.255596658827704,
#  12.368643185555927,
#  12.482074514190167,
#  12.595869250609635,
#  12.710005220554558,
#  12.824459460494236,
#  12.939208179626773,
#  13.05422676730556,
#  13.169489776588522,
#  13.28497092287686,
#  13.400643082363029,
#  13.516478267773007,
#  13.63244762203578,
#  13.748521415744491,
#  13.86466904520269,
#  13.980859032362032,
#  14.09705901299059,
#  14.21323572270145,
#  14.329355009006386,
#  14.445381831891316,
#  14.561280263835796,
#  14.677013482657236,
#  14.79254376957312,
#  14.907832528235058,
#  15.02284028672282,
#  15.137526699631502,
#  15.251850544883713,
#  15.365769748835103,
#  15.47924139842426,
#  15.592221745364045,
#  15.704666211220715,
#  15.816529416297874,
#  15.927765201318696,
#  16.038326634698404,
#  16.148166025356698,
#  16.25723496229242,
#  16.3654843388295,
#  16.47286436659072,
#  16.579324596072638,
#  16.684813971699075,
#  16.78928085127315,
#  16.8926730292116,
#  16.99493777409183,
#  17.096021888136132,
#  17.19587172417042,
#  17.29443322060935,
#  17.39165196434808,
#  17.487473234175095,
#  17.581842030220372,
#  17.67470312361117,
#  17.766001133861792,
#  17.85568055463083,
#  17.94368580167104,
#  18.02996129229989,
#  18.114451494825982,
#  18.19710096934031,
#  18.27785443785084,
#  18.356656863680925,
#  18.433453486556395,
#  18.5081898843761,
#  18.580812069132826,
#  18.651266526123134,
#  18.719500272804495,
#  18.78546095068792,
#  18.849096883931644,
#  18.91035712939886,
#  18.969191561559324,
#  19.025550949327467,
#  19.07938699929147,
#  19.13065243168935,
#  19.179301069079333,
#  19.22528787638904,
#  19.268569028836424,
#  19.309102003174903,
#  19.346845617672038,
#  19.381760094006488,
#  19.41380714248307,
#  19.442950004622023,
#  19.469153507461538,
#  19.492384140530547,
#  19.512610098896012,
#  19.529801329668928,
#  19.543929599574895,
#  19.55496853500157,
#  19.56289366123939,
#  19.56768245947985,
#  19.569314400750045,
#  19.567770978227852,
#  19.563035752504952,
#  19.555094377255042,
#  19.543934624477814,
#  19.52954641682149,
#  19.511921844093155,
#  19.491055180643936,
#  19.466942903738264,
#  19.439583701114085,
#  19.408978479086574,
#  19.375130366631677,
#  19.33804471474314,
#  19.29772909326554,
#  19.254193281788577,
#  19.207449261325532,
#  19.157511197228686,
#  19.104395420579095,
#  19.04812041047722,
#  18.988706762470596,
#  18.926177164004244,
#  18.860556364505882,
#  18.79187113200484,
#  18.720150224192107,
#  18.645424342509475,
#  18.567726084790785,
#  18.487089907868064,
#  18.403552066510716,
#  18.317150568257688,
#  18.227925121472573,
#  18.13591706742596,
#  18.04116933567556,
#  17.943726373739104,
#  17.843634085919906,
#  17.740939777684712,
#  17.63569207627789,
#  17.527940877489414,
#  17.417737272624954,
#  17.305133475672406,
#  17.190182766256314,
#  17.072939405029036,
#  16.95345857510575,
#  16.831796308885416,
#  16.708009411124586,
#  16.582155401333107,
#  16.454292429364475,
#  16.324479216542723,
#  16.192774983037385,
#  16.059239374766438,
#  15.923932405673947,
#  15.786914378364619,
#  15.648245829571648,
#  15.507987458201724,
#  15.3662000635092,
#  15.222944486141072,
#  15.07828154079658,
#  14.93227196476347,
#  14.7849763526445,
#  14.636455106468043,
#  14.486768377126896,
#  14.33597601437962,
#  14.18413751438065,
#  14.031311972304191,
#  13.877558033128267,
#  13.722933850511613,
#  13.567497037240573,
#  13.411304632760547,
#  13.254413055225953,
#  13.096878068604397,
#  12.938754752002575,
#  12.780097454923196,
#  12.620959775243072,
#  12.461394532532948,
#  12.301453727971403,
#  12.141188528647074,
#  11.98064924816071,
#  11.819885313416963,
#  11.6589452484313,
#  11.497876662635155,
#  11.336726233760805,
#  11.175539682594987,
#  11.01436176852947,
#  10.853236281451013,
#  10.692206030315138,
#  10.531312827426081,
#  10.370597487179584,
#  10.210099823940302,
#  10.049858648984976,
#  9.889911762421011,
#  9.730295952235458,
#  9.571046996732807,
#  9.412199668787567,
#  9.253787736559929,
#  9.09584396654,
#  8.938400123612169,
#  8.78148698118447,
#  8.625134327026933,
#  8.469370973838101,
#  8.314224766993064,
#  8.159722584587417,
#  8.005890352970672,
#  7.852753056351686,
#  7.700334752702269,
#  7.548658586012599,
#  7.397746786339667,
#  7.247620688163811,
#  7.098300743862623,
#  6.949806542768528,
#  6.802156825301466,
#  6.65536948355983,
#  6.509461584399392,
#  6.364449381085518,
#  6.220348338712889,
#  6.077173143845396,
#  5.934937708253293,
#  5.7936551960544325,
#  5.653338034632565,
#  5.5139979414711,
#  5.375645927216872,
#  5.2382923096968215,
#  5.101946735141359,
#  4.966618197900118,
#  4.832315056148436,
#  4.699045035271579,
#  4.566815252603442,
#  4.435632230837966,
#  4.30550192218261,
#  4.176429711179311,
#  4.048420432242322,
#  3.9214783855993205,
#  3.795607360200559,
#  3.670810641794352,
#  3.547091021611728,
#  3.424450817502014,
#  3.302891890028462,
#  3.182415657206249,
#  3.0630230984316675,
#  2.9447147752095177,
#  2.827490844315087,
#  2.7113510754316,
#  2.5962948538099755,
#  2.482321197875723,
#  2.3694287717078923,
#  2.2576159028246847,
#  2.1468805852784683,
#  2.0372204936710823,
#  1.9286329956830512,
#  1.821115168455475,
#  1.7146638027171037,
#  1.6092754136062006,
#  1.5049462533729738,
#  1.4016723256370143,
#  1.2994493904551658,
#  1.1982729727417187,
#  1.0981383748649456,
#  0.9990406887474661,
#  0.9009748013205815,
#  0.8039354015471577,
#  0.7079169923403084,
#  0.6129139009512586,
#  0.5189202840002187,
#  0.4259301341858559,
#  0.3339372909087677,
#  0.2429354494097909,
#  0.15291816463356395,
#  0.06387885862649363,
#  -0.024189169854790582,
#  -0.11129273963171521,
#  -0.19743878190088116,
#  -0.28263433212316813,
#  -0.366886523718363,
#  -0.4502025836079037,
#  -0.5325898254802028,
#  -0.6140556422260643,
#  -0.69460750350604,
#  -0.7742529494661721,
#  -0.8529995851800563,
#  -0.9308550730638265,
#  -1.007827131702212,
#  -1.0839235321472005,
#  -1.159152090209722,
#  -1.2335206624225623,
#  -1.3070371395890372,
#  -1.3797094467038886,
#  -1.4515455421515495,
#  -1.522553406481351,
#  -1.592741042374802,
#  -1.6621164677023903,
#  -1.7306877134006926,
#  -1.7984628234723747,
#  -1.865449854459576,
#  -1.9316568638434135,
#  -1.9970919099719324,
#  -2.061763048982435,
#  -2.1256783324973916,
#  -2.1888458076244386,
#  -2.251273515313661,
#  -2.312969480807336,
#  -2.373941715446091,
#  -2.4341982131879596,
#  -2.4937469500918352,
#  -2.552595884273052,
#  -2.610752950652351,
#  -2.6682260574257852,
#  -2.7250230860903892,
#  -2.7811518898773024,
#  -2.8366202937517673,
#  -2.8914360928124885,
#  -2.9456070460656765,
#  -2.9991408777805897,
#  -3.0520452759938763,
#  -3.104327892396405,
#  -3.155996342024325,
#  -3.2070581983124504,
#  -3.257520992411396,
#  -3.3073922132644,
#  -3.356679307227922,
#  -3.405389678067298,
#  -3.4535306843754205,
#  -3.5011096363216443,
#  -3.548133797192756,
#  -3.5946103829647065,
#  -3.6405465623026103,
#  -3.6859494557971324,
#  -3.7308261317699083,
#  -3.7751836075013117,
#  -3.8190288495550964,
#  -3.8623687737253443,
#  -3.9052102449449375,
#  -3.9475600744150934,
#  -3.9894250184930704,
#  -4.030811780399893,
#  -4.071727010187638,
#  -4.1121773047394585,
#  -4.152169206799864,
#  -4.191709201842235,
#  -4.230803720101658,
#  -4.269459137135602,
#  -4.307681773820742,
#  -4.345477896245215,
#  -4.3828537132594105,
#  -4.41981537613669,
#  -4.456368980622046,
#  -4.492520567009017,
#  -4.528276120139681,
#  -4.56364156873628,
#  -4.598622782805645,
#  -4.633225575802487,
#  -4.667455705575299,
#  -4.701318874366396,
#  -4.734820728789855,
#  -4.767966858236743,
#  -4.800762793981684,
#  -4.833214011784843,
#  -4.865325932153659,
#  -4.897103920342833,
#  -4.928553286189491,
#  -4.959679281975231,
#  -4.990487103559213,
#  -5.020981892278437,
#  -5.051168734985719,
#  -5.081052664049695,
#  -5.110638656942324,
#  -5.1399316342189545,
#  -5.1689364619592295,
#  -5.197657952861788,
#  -5.226100866244285,
#  -5.2542699080526845,
#  -5.2821697301634485,
#  -5.309804928959064,
#  -5.337180048213091,
#  -5.364299579686384,
#  -5.391167963127097,
#  -5.417789586293892,
#  -5.444168784069785,
#  -5.470309837642484,
#  -5.496216977390059,
#  -5.521894383251084,
#  -5.547346184724634,
#  -5.572576460907169,
#  -5.59758923959036,
#  -5.62238849672502,
#  -5.646978159253528,
#  -5.671362105404919,
#  -5.695544164694879,
#  -5.719528117971053,
#  -5.743317696670783,
#  -5.766916582165683,
#  -5.790328408618073,
#  -5.813556763311212,
#  -5.836605186649288,
#  -5.859477172192661,
#  -5.882176166241115,
#  -5.904705566722173,
#  -5.9270687260784864,
#  -5.9492689517775155,
#  -5.971309506311527,
#  -5.993193607203763,
#  -6.014924426981641,
#  -6.036505091603498,
#  -6.057938683020047,
#  -6.079228240147285,
#  -6.100376758866492,
#  -6.121387192024234,
#  -6.142262449552433,
#  -6.163005397171697,
#  -6.183618857570407,
#  -6.204105612325568,
#  -6.2244684019285,
#  -6.244709925784832,
#  -6.264832842285416,
#  -6.284839768386744,
#  -6.304733278833566,
#  -6.3245159088777205,
#  -6.344190154619322,
#  -6.36375847300675,
#  -6.383223281836656,
#  -6.402586959917346,
#  -6.421851845707405,
#  -6.441020238840849,
#  -6.460094401694388,
#  -6.4790765593923,
#  -6.497968899806434,
#  -6.516773573601894,
#  -6.535492694126575,
#  -6.554128336213208,
#  -6.572682538772354,
#  -6.591157305310931,
#  -6.609554603932204,
#  -6.627876367335793,
#  -6.6461244929418815,
#  -6.6643008422798475,
#  -6.682407240745497,
#  -6.700445479957633,
#  -6.7184173179173206,
#  -6.736324479007885,
#  -6.754168653994909,
#  -6.771951500194281,
#  -6.789674640570792,
#  -6.807339664134737,
#  -6.824948127934913,
#  -6.842501557116434,
#  -6.8600014449207345,
#  -6.877449252685569,
#  -6.894846410022764,
#  -6.912194313886911,
#  -6.929494329043619,
#  -6.94674778994664,
#  -6.963956000782602,
#  -6.981120235471015,
#  -6.998241737664268,
#  -7.0153217208993786,
#  -7.032361367900433,
#  -7.049361830547712,
#  -7.066324231916922,
#  -7.083249666373401,
#  -7.100139199572121,
#  -7.116993868457684,
#  -7.1338146813444965,
#  -7.150602617705372,
#  -7.167358627246407,
#  -7.184083632140135,
#  -7.2007785273267935,
#  -7.2174441805143275,
#  -7.234081432178388,
#  -7.250691095564331,
#  -7.267273956912758,
#  -7.283830774064252,
#  -7.300362278060216,
#  -7.316869174113845,
#  -7.3333521416101215,
#  -7.34981183410582,
#  -7.366248879329505,
#  -7.382663879300847,
#  -7.399057409905567,
#  -7.415430020345552,
#  -7.431782235169609,
#  -7.4481145544368506,
#  -7.464427453716683,
#  -7.480721384088816,
#  -7.496996772143257,
#  -7.513254020204249,
#  -7.529493505195796,
#  -7.54571557951309,
#  -7.561920572341851,
#  -7.578108789663302,
#  -7.594280514254173,
#  -7.610436005686702,
#  -7.6265755003392135,
#  -7.642699211617359,
#  -7.658807328543814,
#  -7.674900017432592,
#  -7.690977422641306,
#  -7.7070396665711645,
#  -7.7230868496669745,
#  -7.739119050417141,
#  -7.755136325383155,
#  -7.771138709366095,
#  -7.78712621402667,
#  -7.80309882973331,
#  -7.819056526129023,
#  -7.8349992521313885,
#  -7.850926935932559,
#  -7.8668394849992636,
#  -7.8827367860986035,
#  -7.8986187055290165,
#  -7.9144850876968835,
#  -7.93033575690453,
#  -7.9461705179661735,
#  -7.961989156207933,
#  -7.977791437467821,
#  -7.993577108095748,
#  -8.009345894958336,
#  -8.025097505797094,
#  -8.040831627808094,
#  -8.056547929061464,
#  -8.072246059409157,
#  -8.087925650484937,
#  -8.103586315704398,
#  -8.119227650264948,
#  -8.134849231145823,
#  -8.150450617442223,
#  -8.16603134942753,
#  -8.181590948956021,
#  -8.19712892098088,
#  -8.212644753567645,
#  -8.228137917894188,
#  -8.243607868250734,
#  -8.25905404203985,
#  -8.274475859978317,
#  -8.289872725953034,
#  -8.305244026133732,
#  -8.320589131052673,
#  -8.335907395773955,
#  -8.35119815989351,
#  -8.366460747539112,
#  -8.381694467370364,
#  -8.3968986126246,
#  -8.412072461670473,
#  -8.427215276343102,
#  -8.442326303857236,
#  -8.457404777495038,
#  -8.472449916606086,
#  -8.487460926607381,
#  -8.502436998983338,
#  -8.517377311285793,
#  -8.532281027655712,
#  -8.547147298010808,
#  -8.56197525819291,
#  -8.576764031769063,
#  -8.591512730049573,
#  -8.606220452088007,
#  -8.620886284681198,
#  -8.63550930236924,
#  -8.650088567636978,
#  -8.664623131397162,
#  -8.679112031363772,
#  -8.693554294473678,
#  -8.707948937242692,
#  -8.722294965765569,
#  -8.736591375716003,
#  -8.75083715234663,
#  -8.765031270494278,
#  -8.779172695550551,
#  -8.793260381843716,
#  -8.80729327392133,
#  -8.821270307918862,
#  -8.83519041155969,
#  -8.849052504155106,
#  -8.862855496604306,
#  -8.876598291394405,
#  -8.890279783070888,
#  -8.903898858451003,
#  -8.917454395345185,
#  -8.930945265179577,
#  -8.944370333156513,
#  -8.957728458254516,
#  -8.971018493228303,
#  -8.984239284608783,
#  -8.997389672787758,
#  -9.010468493311091,
#  -9.023474574651368,
#  -9.036406740487154,
#  -9.049263810638244,
#  -9.06204460106567,
#  -9.074747923871694,
#  -9.087372587299804,
#  -9.099917395734726,
#  -9.112381150609277,
#  -9.124762649955336,
#  -9.137060687962098,
#  -9.149274057455758,
#  -9.161401549933457,
#  -9.173441955563293,
#  -9.185394063184312,
#  -9.197256660306506,
#  -9.209028533389663,
#  -9.220708469152559,
#  -9.232295252169756,
#  -9.243787667806096,
#  -9.255184502769374,
#  -9.266484545110346,
#  -9.277686584222712]

# %%
#όπως βλέπουμε η τελευταία τιμή του future window είναι η 850 
df.head(850)
# Out:
#               x          y          z
# t
# 0.000  1.000000   1.000000   1.000000
# 0.001  1.000130   1.025989   0.998349
# 0.002  1.000516   1.051961   0.996728
# 0.003  1.001158   1.077922   0.995138
# 0.004  1.002051   1.103879   0.993579
# ...         ...        ...        ...
# 0.845 -9.232295 -10.386275  26.647202
# 0.846 -9.243788 -10.388270  26.672068
# 0.847 -9.255185 -10.390049  26.697004
# 0.848 -9.266485 -10.391609  26.722006
# 0.849 -9.277687 -10.392950  26.747073
#
# [850 rows x 3 columns]

# %% [markdown]
# ## Στή συνέχεια ελέγχουμε να έχουν ίδιο μήκος τα input(windows) με τα target(future_windows)

# %%
print(len(windows))
print(len(future_windows))
# Out:
# 49942
# 49802

# %%
# προφανώς το μήκος του future window έχει 800 τιμές λιγότερες επομένως να κάνουμε τα παράθυρα να έχουν ίδιο μήκος
windows=windows[:len(future_windows)]
print(len(windows))
print(len(future_windows))
# στην περίπτωση που το future window είναι μικρότερο απο το window πρέπει να προσέξουμε να κάνουμε την αντίστοιχη μετατροπή στο future_windows
# Out:
# 49802
# 49802

# %%
inputt= np.array(windows)           
target = np.array(future_windows)

# %% [markdown]
# ### Αυτό σχεδιάζει το 1ό παράθυρο εισόδου (δηλαδή το 50-βηματικό ιστορικό τιμών από t=0 έως t=0.49),
# ### ώστε να μπορείτε να δείτε πώς μοιάζει ένα τυπικό δείγμα εκπαίδευσης.

# %%
plt.plot(inputt[0])

# %% [markdown]
# ### Αυτό σχεδιάζει το 1ό παράθυρο target (δηλαδή το 800-βηματικό ιστορικό τιμών από t=0 έως t=0.849),
# ### ώστε να μπορείτε να δείτε πώς μοιάζει ένα τυπικό δείγμα εκπαίδευσης.

# %%
plt.plot(target[0])

# %% [markdown]
# ## Διαχωρισμός σε training set & test set
# ### Το πρώτο 80% θα χρησιμοποιηθεί για το training set

# %%
# Διαχωρισμός σε 80% train / 20% test
ts = round(len(inputt) * 0.8)

train_set = inputt[:ts]
test_set = target[:ts]

y_train = inputt[ts:]
y_test = target[ts:]

# %% [markdown]
# ## Εισάγουμε κάποιες βιβλιοθήκες
# ### 1) from sklearn.linear_model import Ridge
# ### Η παλινδρόμηση Ridge θα είναι το read‐out layer: ένα γραμμικό μοντέλο με L₂ κανονικοποίηση,
# ### που μαθαίνει να χαρτογραφεί τις καταστάσεις του reservoir στις τιμές‐στόχους.
# ### 2) from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
# ### Το GridSearchCV εκτελεί εξαντλητική αναζήτηση σε πλέγμα υπερπαραμέτρων
# ### (π.χ. διαφορετικά spectral_radius, leakage κ.λπ.), χρησιμοποιώντας cross‐validation
# ### για να επιλέξει τον καλύτερο συνδυασμό.
# ### Το TimeSeriesSplit είναι καταμεριστής cross‐validation που διατηρεί τη χρονολογική σειρά
# ### (χωρίς τυχαιοποίηση), παρέχοντας σωστά train/test folds για χρονοσειρές.
# ### 3) from sklearn.metrics import make_scorer, mean_squared_error
# ### Το mean_squared_error είναι η συνάρτηση κόστους (loss) που θα ελαχιστοποιήσετε.
# ### Το make_scorer(mean_squared_error, greater_is_better=False) το “τυλίγει”
# ### ώστε να μπορεί να περαστεί στο GridSearchCV (απαιτεί αντικείμενο scorer).
# ### 4) from pyrcn.model_selection import SequentialSearchCV
# ### Ένας PyRCN‐specific orchestrator που εκτελεί διαδοχικά βήματα tuning
# ### (π.χ. πρώτα input_scaling, μετά spectral_radius κ.λπ.), σταθεροποιώντας
# ### κάθε φορά τις καλύτερες παραμέτρους.
# ### 5) from pyrcn.metrics import mean_squared_error
# ### Η δική του έκδοση του MSE στο PyRCN (ίδια μαθηματικά αλλά συμβατή με το API).
# ### 6) from pyrcn.echo_state_network import ESNRegressor
# ### Η κύρια κλάση που υλοποιεί το Echo State Network για regression.
# ### Τη δημιουργείτε με τα blocks InputToNode και NodeToNode, συν ένα read‐out (Ridge).
# ### 7) from pyrcn.base.blocks import InputToNode, NodeToNode
# ### Το InputToNode καθορίζει πώς οι είσοδοι τροφοδοτούνται (και κλιμακώνονται)
# ### σε κάθε νευρώνα του reservoir.
# ### Το NodeToNode καθορίζει τις εσωτερικές επαναληπτικές συνδέσεις
# ### (μέγεθος, spectral radius, leakage, sparsity κ.λπ.).
# ### 8) from matplotlib import pyplot as plt
# ### Βασική βιβλιοθήκη σχεδιασμού γραφημάτων για οπτικοποίηση:
# ### καμπύλες κόστους, προβλέψεις vs πραγματικά, RMSE vs υπερπαράμετροι κ.λπ.

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer,mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

from pyrcn.model_selection import SequentialSearchCV
from pyrcn.metrics import mean_squared_error
from pyrcn.echo_state_network import ESNRegressor
from pyrcn.base.blocks import InputToNode, NodeToNode
from sklearn.metrics import make_scorer,mean_squared_error

from matplotlib import pyplot as plt

# %% [markdown]
# # Βήμα 1: Αρχική ρύθμιση και Grid Search του
# ## i) Ορίζει ένα Echo State Network (ESN) με κάποιες σταθερές βασικές παραμέτρους
# ## ii) Ορίζει και ένα σετ υπερπαραμέτρων (όπως leakage, spectral_radius, input_scaling) που θες να βελτιστοποιήσεις
# ## iii) Χρησιμοποιεί Grid Search (μέσω του SequentialSearchCV) για να βρει το βέλτιστο συνδυασμό παραμέτρων
# ## iv) Κάνει εκπαίδευση με cross-validation στο training set
# ## v) Τέλος, εμφανίζει το καλύτερο μοντέλο που βρέθηκε

# %%
# Απενεργοποιούμε όλες τις προειδοποιήσεις για καθαρό output
import warnings
warnings.filterwarnings('ignore')

# initially_fixed_params: λεξικό με σταθερές παραμέτρους του ESN για αυτό το βήμα.
#   hidden_layer_size=400      : αριθμός κόμβων στο reservoir
#   input_activation='identity': χωρίς μη γραμμικό μετασχηματισμό εισόδου
#   reservoir_activation='tanh': ενεργοποίηση μέσα στο reservoir
#   bidirectional=False        : καμία οπισθοδρόμηση (μόνο προς τα εμπρός)
#   alpha=1e-5                 : δύναμη κανονικοποίησης Ridge για το read-out
#   k_rec=10                   : κάθε κόμβος έχει 10 επαναληπτικές συνδέσεις
#   random_state=42            : αναπαραγωγιμότητα τυχαίων βαρών
#   requires_sequence=False    : δεν απαιτείται η ολόκληρη ακολουθία κατά το fit
initially_fixed_params = {
    'hidden_layer_size': 400,
    'input_activation': 'identity',
    'reservoir_activation': 'tanh',
    'bidirectional': False,
    'alpha': 1e-5,
    'k_rec': 10,
    'random_state': 42,
    'requires_sequence': False
}

# step1_esn_params: grid υπερπαραμέτρων για το πρώτο tuning βήμα
#   → συνολικά 2×2×2 = 8 δυνατότητες
step1_esn_params = {
    'input_scaling':  (0.1,0.2,0.6),
    'spectral_radius': (0.1,0.6),
    'leakage':         (0.8,0.9,1)}

# Μετατρέπουμε το MSE σε scorer για το GridSearchCV, ώστε να το ελαχιστοποιεί
from sklearn.metrics import make_scorer, mean_squared_error
scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)

# Επιπλέον kwargs για το GridSearchCV:
#   verbose=5 : εμφάνιση προόδου ανά fold
#   scoring=scorer : χρήση του MSE scorer
#   n_jobs=1 : σειριακή εκτέλεση (θέσε -1 για παράλληλη)
kwargs_step1 = {
    'verbose': 5,
    'scoring': scorer,
    'n_jobs': 1
}

# Καθορίζουμε το βήμα αναζήτησης:
#   ('βημα', ΜέθοδοςCV, grid παραμέτρων, επιπλέον kwargs)
searches = [
    ('step1', GridSearchCV, step1_esn_params, kwargs_step1)
]

# Δημιουργούμε το ESNRegressor με Ridge read-out και τις σταθερές παραμέτρους
from sklearn.linear_model import Ridge
from pyrcn.echo_state_network import ESNRegressor
esn = ESNRegressor(regressor=Ridge(), **initially_fixed_params)

# Εκτελούμε SequentialSearchCV: 
#   1) παίρνει το base ESN
#   2) τρέχει το 'step1' grid search (8 συνδυασμοί) με TimeSeriesSplit
#   3) επιλέγει τις βέλτιστες input_scaling, spectral_radius, leakage
from pyrcn.model_selection import SequentialSearchCV
esn_opti = SequentialSearchCV(esn, searches=searches).fit(train_set,test_set)

# Εμφανίζουμε το βελτιστοποιημένο ESN με τις επιλεγμένες παραμέτρους
print(esn_opti)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.1;, score=-149.338 total time=  10.7s
# [CV 2/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.1;, score=-50.473 total time=   4.3s
# [CV 3/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.1;, score=-12.770 total time=   4.0s
# [CV 4/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.1;, score=-129.963 total time=   3.7s
# [CV 5/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.1;, score=-53.745 total time=   4.0s
# [CV 1/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.6;, score=-7064.943 total time=   4.0s
# [CV 2/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.6;, score=-673.030 total time=   3.7s
# [CV 3/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.6;, score=-1168.317 total time=   3.8s
# [CV 4/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.6;, score=-3708.397 total time=   4.2s
# [CV 5/5] END input_scaling=0.1, leakage=0.8, spectral_radius=0.6;, score=-542.139 total time=   4.4s
# [CV 1/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.1;, score=-69.255 total time=   4.8s
# [CV 2/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.1;, score=-262.840 total time=   5.0s
# [CV 3/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.1;, score=-8.020 total time=   4.5s
# [CV 4/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.1;, score=-31.807 total time=   4.8s
# [CV 5/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.1;, score=-23.370 total time=   4.3s
# [CV 1/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.6;, score=-567.090 total time=   4.5s
# [CV 2/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.6;, score=-59.340 total time=   5.0s
# [CV 3/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.6;, score=-1182.963 total time=   4.6s
# [CV 4/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.6;, score=-2115.779 total time=   4.8s
# [CV 5/5] END input_scaling=0.1, leakage=0.9, spectral_radius=0.6;, score=-556.343 total time=   4.2s
# [CV 1/5] END input_scaling=0.1, leakage=1, spectral_radius=0.1;, score=-20.100 total time=   4.5s
# [CV 2/5] END input_scaling=0.1, leakage=1, spectral_radius=0.1;, score=-53.197 total time=   5.1s
# [CV 3/5] END input_scaling=0.1, leakage=1, spectral_radius=0.1;, score=-13.027 total time=   4.5s
# [CV 4/5] END input_scaling=0.1, leakage=1, spectral_radius=0.1;, score=-71.156 total time=   4.4s
# [CV 5/5] END input_scaling=0.1, leakage=1, spectral_radius=0.1;, score=-66.439 total time=   4.5s
# [CV 1/5] END input_scaling=0.1, leakage=1, spectral_radius=0.6;, score=-9187.305 total time=   4.2s
# [CV 2/5] END input_scaling=0.1, leakage=1, spectral_radius=0.6;, score=-358.457 total time=   4.3s
# [CV 3/5] END input_scaling=0.1, leakage=1, spectral_radius=0.6;, score=-1583.103 total time=   4.8s
# [CV 4/5] END input_scaling=0.1, leakage=1, spectral_radius=0.6;, score=-233.836 total time=   4.6s
# [CV 5/5] END input_scaling=0.1, leakage=1, spectral_radius=0.6;, score=-860.342 total time=   4.5s
# [CV 1/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.1;, score=-51.560 total time=   4.4s
# [CV 2/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.1;, score=-10.624 total time=   5.5s
# [CV 3/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.1;, score=-81.626 total time=   4.6s
# [CV 4/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.1;, score=-38.953 total time=   4.7s
# [CV 5/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.1;, score=-18.501 total time=   7.6s
# [CV 1/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.6;, score=-7092.007 total time=   4.7s
# [CV 2/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.6;, score=-343.686 total time=   4.9s
# [CV 3/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.6;, score=-2856.136 total time=   4.3s
# [CV 4/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.6;, score=-94.703 total time=   4.5s
# [CV 5/5] END input_scaling=0.2, leakage=0.8, spectral_radius=0.6;, score=-1032.127 total time=   4.9s
# [CV 1/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.1;, score=-78.287 total time=   5.0s
# [CV 2/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.1;, score=-149.267 total time=   4.6s
# [CV 3/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.1;, score=-212.946 total time=   5.0s
# [CV 4/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.1;, score=-37.546 total time=   4.8s
# [CV 5/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.1;, score=-274.943 total time=   4.6s
# [CV 1/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.6;, score=-1077.929 total time=   5.9s
# [CV 2/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.6;, score=-92.868 total time=   6.5s
# [CV 3/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.6;, score=-2143.208 total time=   5.4s
# [CV 4/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.6;, score=-82.628 total time=   4.3s
# [CV 5/5] END input_scaling=0.2, leakage=0.9, spectral_radius=0.6;, score=-2465.184 total time=   4.4s
# [CV 1/5] END input_scaling=0.2, leakage=1, spectral_radius=0.1;, score=-707.365 total time=   3.9s
# [CV 2/5] END input_scaling=0.2, leakage=1, spectral_radius=0.1;, score=-47.394 total time=   3.9s
# [CV 3/5] END input_scaling=0.2, leakage=1, spectral_radius=0.1;, score=-39.467 total time=   3.9s
# [CV 4/5] END input_scaling=0.2, leakage=1, spectral_radius=0.1;, score=-53.640 total time=   4.0s
# [CV 5/5] END input_scaling=0.2, leakage=1, spectral_radius=0.1;, score=-171.310 total time=   4.0s
# [CV 1/5] END input_scaling=0.2, leakage=1, spectral_radius=0.6;, score=-4083.600 total time=   4.0s
# [CV 2/5] END input_scaling=0.2, leakage=1, spectral_radius=0.6;, score=-363.704 total time=   4.0s
# [CV 3/5] END input_scaling=0.2, leakage=1, spectral_radius=0.6;, score=-991.223 total time=   4.0s
# [CV 4/5] END input_scaling=0.2, leakage=1, spectral_radius=0.6;, score=-692.676 total time=   4.1s
# [CV 5/5] END input_scaling=0.2, leakage=1, spectral_radius=0.6;, score=-1953.523 total time=   4.1s
# [CV 1/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.1;, score=-52.844 total time=   4.0s
# [CV 2/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.1;, score=-35.175 total time=   4.0s
# [CV 3/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.1;, score=-6.241 total time=   4.0s
# [CV 4/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.1;, score=-9.153 total time=   4.0s
# [CV 5/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.1;, score=-50.581 total time=   4.0s
# [CV 1/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.6;, score=-537.504 total time=   4.1s
# [CV 2/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.6;, score=-187.239 total time=   4.0s
# [CV 3/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.6;, score=-16.585 total time=   3.9s
# [CV 4/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.6;, score=-35.059 total time=   4.0s
# [CV 5/5] END input_scaling=0.6, leakage=0.8, spectral_radius=0.6;, score=-72.144 total time=   4.0s
# [CV 1/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.1;, score=-107.750 total time=   4.2s
# [CV 2/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.1;, score=-76.498 total time=   4.1s
# [CV 3/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.1;, score=-13.119 total time=   4.1s
# [CV 4/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.1;, score=-9.190 total time=   4.1s
# [CV 5/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.1;, score=-22.483 total time=   4.1s
# [CV 1/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.6;, score=-276.080 total time=   4.3s
# [CV 2/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.6;, score=-355.974 total time=   4.1s
# [CV 3/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.6;, score=-29.931 total time=   4.3s
# [CV 4/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.6;, score=-16.163 total time=   4.3s
# [CV 5/5] END input_scaling=0.6, leakage=0.9, spectral_radius=0.6;, score=-670.338 total time=   4.9s
# [CV 1/5] END input_scaling=0.6, leakage=1, spectral_radius=0.1;, score=-126.224 total time=   5.0s
# [CV 2/5] END input_scaling=0.6, leakage=1, spectral_radius=0.1;, score=-37.321 total time=   5.1s
# [CV 3/5] END input_scaling=0.6, leakage=1, spectral_radius=0.1;, score=-6.473 total time=   5.5s
# [CV 4/5] END input_scaling=0.6, leakage=1, spectral_radius=0.1;, score=-11.523 total time=   5.6s
# [CV 5/5] END input_scaling=0.6, leakage=1, spectral_radius=0.1;, score=-39.862 total time=   5.4s
# [CV 1/5] END input_scaling=0.6, leakage=1, spectral_radius=0.6;, score=-323.719 total time=   4.9s
# [CV 2/5] END input_scaling=0.6, leakage=1, spectral_radius=0.6;, score=-86.175 total time=   4.7s
# [CV 3/5] END input_scaling=0.6, leakage=1, spectral_radius=0.6;, score=-82.014 total time=   4.1s
# [CV 4/5] END input_scaling=0.6, leakage=1, spectral_radius=0.6;, score=-18.334 total time=   4.4s
# [CV 5/5] END input_scaling=0.6, leakage=1, spectral_radius=0.6;, score=-95.509 total time=   5.0s
# SequentialSearchCV(estimator=ESNRegressor(input_to_node=InputToNode(hidden_layer_size=400,
#                                                                     input_activation='identity',
#                                                                     input_scaling=0.6),
#                                           node_to_node=NodeToNode(hidden_layer_size=400,
#                                                                   k_rec=10,
#                                                                   leakage=0.8,
#                                                                   sparsity=0.025,
#                                                                   spectral_radius=0.1),
#                                           regressor=Ridge(alpha=1e-05,
#                                                           random_state=42),
#                                           requires_sequence=False),
#                    searches=[('step1',
#                               <class 'sklearn.model_selection._search.GridSearchCV'>,
#                               {'input_scaling': (0.1, 0.2, 0.6),
#                                'leakage': (0.8, 0.9, 1),
#                                'spectral_radius': (0.1, 0.6)},
#                               {'n_jobs': 1,
#                                'scoring': make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#                                'verbose': 5})])

# %% [markdown]
# ## Φτιαχνουμε μία συνάρτηση που θα υπολογίζει την ελάχιστη τιμή μέσα σε μία λίστα , αυτό θα μας βοηθήσει να ΄βρίσκουμε το ελάχιστο rmse

# %%
def find_min_with_index(lst):
    if not lst:
        raise ValueError("Η λίστα είναι κενή")

    minimum = lst[0]
    min_index = 0

    for i in range(1, len(lst)):  # 👈 i goes from 1 to len(lst) - 1
        if lst[i] < minimum:
            minimum = lst[i]
            min_index = i
    return minimum, min_index

# %% [markdown]
# ## Δοκιμάζουμε διάφορες τιμές για το Input Scaling για να βρούμε την βέλτιστη

# %%
## Καθορίζουμε την λίστα υποψήφιων input_scaling τιμών
in_scaling = [0.1,0.2,0.3,0.4,0.6,0.8]

# %%
# Δημιουργούμε μια λίστα για να αποθηκεύσουμε τα RMSE για κάθε input_scaling
rmses = list()
# Βρόχος πάνω σε όλες τις τιμές του in_scaling
for i in range(len(in_scaling)):
    in_s = in_scaling[i]  # τρέχουσα τιμή input_scaling

    # Ορίζουμε το μπλοκ που τροφοδοτεί το reservoir με είσοδο

    base_input_to_nodes = InputToNode(
        hidden_layer_size=800,        # πλήθος κόμβων reservoir
        input_activation='identity',  # χωρίς μη γραμμική ενεργοποίηση στην είσοδο
        k_in=1,                       # κάθε είσοδος συνδέεται με κάθε κόμβο
        input_scaling=in_s,           # κλιμάκωση εισόδου
        bias_scaling=0.0              # χωρίς bias
    )
    
     # Ορίζουμε τις επαναληπτικές συνδέσεις του reservoir
    base_nodes_to_nodes = NodeToNode(
        hidden_layer_size=800, # ίδιο πλήθος κόμβων
        spectral_radius=0.1,   # σταθερή φασματική ακτίνα
        leakage=0.2,           # σταθερός ρυθμός διαρροής
        k_rec=10               # κάθε κόμβος συνδέεται με 10 τυχαίους
    )
     
    # Δημιουργούμε το ESN με Ridge read-out
    esn = ESNRegressor(
        input_to_node=base_input_to_nodes,
        node_to_node=base_nodes_to_nodes,
        regressor=Ridge(alpha=1e-8),
        n_readout_inits=50  #n_readout_inits=50 πεταει τα πρωτα 50 βηματα για να σταθεροποιηθεί το Reservoir
    )
    
    # Εκπαιδεύουμε το ESN πάνω στο training set
    esn.fit(train_set, test_set)
    
    # Παράγουμε προβλέψεις για το ίδιο training set
    predictions = esn.predict(train_set)
    
    # Υπολογίζουμε το MSE και έπειτα το RMSE
    MSE = mean_squared_error(predictions,test_set)
    rmse = math.sqrt(MSE)
        
    # Εκτυπώνουμε και αποθηκεύουμε το RMSE
    print(rmse)
    rmses.append(rmse)
# Out:
# 1.6445486137905199
# 1.3513901361528478
# 1.1726846831807796
# 1.0653311364909315
# 0.9633179485867507
# 0.9879184077319584

# %% [markdown]
# ## Χρησιμοποιούμε την συνάρτηση που βρίσκει την τιμή με το ελάχιστο σφάλμα και τον index της

# %%
minimum, index = find_min_with_index(rmses)

# Τώρα έχεις και την τιμή και το index έξω από τη συνάρτηση
print("Η ελάχιστη τιμή είναι:", minimum)
print("Η θέση της είναι:", index)
print("Το in_scaling που αντιστοιχεί είναι:", in_scaling[index])
# Out:
# Η ελάχιστη τιμή είναι: 0.9633179485867507
# Η θέση της είναι: 4
# Το in_scaling που αντιστοιχεί είναι: 0.6

# %% [markdown]
# ## Φτιάχνουμε ένα διάγραμμα που απεικονίζει πως συμπεριφέρεται το rmse για τις δίαφορες τιμές του input scaling

# %%
import matplotlib.pyplot as plt

# Δημιουργία γραφήματος
plt.figure(figsize=(8, 5))
plt.plot(in_scaling, rmses, marker='o', linestyle='-', linewidth=2, color='darkgreen')

# Τίτλος και άξονες
plt.title("Επίδραση του Input Scaling στο RMSE", fontsize=14)
plt.xlabel("Input Scaling", fontsize=12)
plt.ylabel("RMSE (Σφάλμα πρόβλεψης)", fontsize=12)

# Προσθήκη τιμών RMSE πάνω από κάθε σημείο
for i, rmse in enumerate(rmses):
    plt.text(in_scaling[i], rmse + 0.002, f"{rmse:.3f}", ha='center', fontsize=9)

# Styling
plt.grid(True)
plt.xticks(in_scaling)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Δοκιμάζουμε διάφορες τιμές για τον αριθμό των nodes για να βρούμε την βέλτιστη

# %%
## Καθορίζουμε την λίστα υποψήφιων input_scaling τιμών
nodes = [50,70,100,200,300,400,500,600,700,800]

# %% [markdown]
# ## Θέλουμε να δούμε πώς η απόδοση του ESN (μετρούμενη ως RMSE στο training set) αλλάζει καθώς αλλάζουμε το πλήθος των νευρώνων (nodes) στο εσωτερικό reservoir.
#
# ## Λιγότεροι κόμβοι → μικρότερη χωρητικότητα μνήμης, λιγότερο πολύπλοκο μοντέλο
#
# ## Περισσότεροι κόμβοι → περισσότερη χωρητικότητα, αλλά και κίνδυνος υπερεκπαίδευσης ή μεγαλύτερο κόστος υπολογισμού

# %%
# Εδώ θα αποθηκεύσουμε τα RMSE για κάθε μέγεθος
rmses = []

# Βρόχος πάνω σε κάθε αριθμό κόμβων
for i in range(len(nodes)):
    n_nodes = nodes[i]  # τρέχουσα τιμή hidden_layer_size

    # 1) Ορισμός του μπλοκ εισόδου με n_nodes νευρώνες
    base_input_to_nodes = InputToNode(
        hidden_layer_size=n_nodes,       # πλήθος νευρώνων
        input_activation='identity',     # χωρίς μη-γραμμικότητα στην είσοδο
        k_in=1,                          # πλήρης σύνδεση input → κάθε νευρώνα
        input_scaling=0.6,               # σταθερή κλιμάκωση εισόδου
        bias_scaling=0.0                 # χωρίς bias
    )

    # 2) Ορισμός του μπλοκ επαναληπτικών συνδέσεων (reservoir)
    base_nodes_to_nodes = NodeToNode(
        hidden_layer_size=n_nodes,  # ίδιο πλήθος νευρώνων
        spectral_radius=0.1,        # σταθερή φασματική ακτίνα
        leakage=0.8,                # σταθερή διαρροή μνήμης
        k_rec=10,                   # 10 τυχαίες επαναληπτικές συνδέσεις ανά νευρώνα
              
    )

    # 3) Κατασκευή ESNRegressor με Ridge read‐out
    esn = ESNRegressor(
        input_to_node=base_input_to_nodes,
        node_to_node=base_nodes_to_nodes,
        regressor=Ridge(alpha=1e-8)  # πολύ ελαφριά κανονικοποίηση
    )

    
     # Εκπαιδεύουμε το ESN πάνω στο training set
    esn.fit(train_set, test_set)
    
    # Παράγουμε προβλέψεις για το ίδιο training set
    predictions = esn.predict(train_set)
    
    # Υπολογίζουμε το MSE και έπειτα το RMSE
    MSE = mean_squared_error(predictions,test_set)
    rmse = math.sqrt(MSE)
        
    # Εκτυπώνουμε και αποθηκεύουμε το RMSE
    #Εμφάνιση και αποθήκευση του αποτελέσματος
    print(f"n_nodes={n_nodes} → RMSE={rmse:.20f}")
    rmses.append(rmse)
# Out:
# n_nodes=50 → RMSE=4.20472792954726060088
# n_nodes=70 → RMSE=3.88446978747617466254
# n_nodes=100 → RMSE=4.02313610350932826520
# n_nodes=200 → RMSE=3.49196472552159464797
# n_nodes=300 → RMSE=3.08274835987652018332
# n_nodes=400 → RMSE=2.91241650827276243874
# n_nodes=500 → RMSE=2.59643525750056580748
# n_nodes=600 → RMSE=2.45783831788362716608
# n_nodes=700 → RMSE=2.26778268131894433779
# n_nodes=800 → RMSE=2.22509440430477889450

# %% [markdown]
# ## Χρησιμοποιούμε την συνάρτηση που βρίσκει την τιμή με το ελάχιστο σφάλμα και τον index της

# %%
minimum, index = find_min_with_index(rmses)

# Τώρα έχεις και την τιμή και το index έξω από τη συνάρτηση
print("Η ελάχιστη τιμή είναι:", minimum)
print("Η θέση της είναι:", index)
print("Τα nodes που αντιστοιχεί είναι:", nodes[index])
# Out:
# Η ελάχιστη τιμή είναι: 0.9484045803117835
# Η θέση της είναι: 9
# Τα nodes που αντιστοιχεί είναι: 800

# %% [markdown]
# ## Γράφημα που δείχνει ποσο μεταβάλεται το σφάλμα με βάση των αριθμών των κόμβων που επιλέχθηκε

# %%
plt.figure(figsize=(8, 5))  # Καθαρό μέγεθος για παρουσίαση
plt.plot(nodes, rmses, marker='o', linestyle='-', linewidth=2, color='blue')

# Προσθήκη τίτλου και αξόνων
plt.title("Επίδραση του αριθμού κόμβων (Nodes) στο RMSE", fontsize=14)
plt.xlabel("Αριθμός κόμβων στο Reservoir", fontsize=12)
plt.ylabel("RMSE (Σφάλμα Πρόβλεψης)", fontsize=12)

# Προαιρετικά: εμφάνιση τιμών RMSE πάνω στα σημεία
for i, rmse in enumerate(rmses):
    plt.text(nodes[i], rmses[i] + 0.002, f"{rmse:.3f}", ha='center', fontsize=9)

plt.grid(True)
plt.xticks(nodes)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Σε αυτό το βήμα διαμορφώνουμε την αρχιτεκτονική του Echo State Network, δημιουργώντας:
# ## Το μπλοκ εισόδου (InputToNode) που χαρτογραφεί και κλιμακώνει τις εξωτερικές τιμές στο reservoir.
# ## Το επαναληπτικό μπλοκ (NodeToNode) που ορίζει τη δυναμική και τις εσωτερικές συνδέσεις του reservoir.
# ## Τον τελικό ESNRegressor, συνδυάζοντας τα δύο blocks με έναν γραμμικό Ridge read-out, έτοιμο να εκπαιδευτεί.

# %%
# Ορισμός του μπλοκ εισόδου (Input → Reservoir)
base_input_to_nodes = InputToNode(
    hidden_layer_size=800,   # reservoir με 1000 νευρώνες
    input_activation='identity',  # η είσοδος περνάει αυτούσια, χωρίς μη-γραμμική ενεργοποίηση
    k_in=1,                       # κάθε διάσταση εισόδου συνδέεται με κάθε νευρώνα
    input_scaling=0.6,            # κλιμακώνει την ισχύ του σήματος εισόδου στο 0.4
    bias_scaling=0.0              # δεν προστίθεται επιπλέον bias
)

# Ορισμός του επαναληπτικού μπλοκ (Reservoir → Reservoir)
base_nodes_to_nodes = NodeToNode(
    hidden_layer_size=800,  # ίδια διάσταση reservoir: 1000 νευρώνες
    spectral_radius=0.1,     # φασματική ακτίνα για σταθερότητα της δυναμικής
    leakage=0.9,             # ρυθμός "διαρροής" μνήμης των νευρώνων
    k_rec=10                 # κάθε νευρώνας έχει 10 τυχαίες επαναληπτικές συνδέσεις
)

# Συνδυασμός σε ESNRegressor με Ridge read-out
esn = ESNRegressor(
    input_to_node=base_input_to_nodes,      # το μπλοκ εισόδου που ορίσαμε
    node_to_node=base_nodes_to_nodes,       # το επαναληπτικό μπλοκ
    regressor=Ridge(alpha=1e-8)             # γραμμικός read-out με πολύ ελαφριά κανονικοποίηση
)

# %% [markdown]
# # Training set

# %%
# Εκπαίδευση (fit) του ESN στο training set
#   - Το ESN «μαθαίνει» τον γραμμικό read-out (Ridge) βασιζόμενο στις καταστάσεις του reservoir
#   - Χρησιμοποιεί train_set (X) και y_train (στόχους) για να υπολογίσει τα κατάλληλα βάρη
esn.fit(train_set,test_set)

# Πρόβλεψη (predict) του ίδιου training set
#   - Μετά την εκπαίδευση, παράγει τις τιμές που «πιστεύει» ότι αντιστοιχούν στα train_set
#   - Αποθηκεύουμε το αποτέλεσμα σε predictions_train
predictions_train = esn.predict(train_set)

# %%
# Επίλεξε το δείγμα που θέλεις να προβάλλεις (π.χ. δείγμα #10)
sample_index =34000

# Δημιουργία του διαγράμματος
plt.figure(figsize=(10, 5))

# Προβλέψεις για t+1 έως t+10
plt.plot(
    predictions_train[sample_index],
    label='Πρόβλεψη (t+1 έως t+10)',
    linestyle='--',
    #marker='o',
    #lw=5,
    color='red'
)

# Πραγματικές τιμές για t+1 έως t+10
plt.plot(
    test_set[sample_index],
    label='Πραγματικές τιμές',
    linestyle='-',
    #marker='x',
    #lw=5,
    color='blue'
)

# Επεξηγήσεις και styling
plt.title(f'Πρόβλεψη 10 βημάτων για το training δείγμα #{sample_index}', fontsize=14)
plt.xlabel('Βήμα στο μέλλον (1 = t+1, ..., 10 = t+10)', fontsize=12)
plt.ylabel('Τιμή', fontsize=12)
plt.xticks(ticks=range(10), labels=[f't+{i+1}' for i in range(10)])
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

#plt.rcParams['lines.linewidth'] = 0.5

# %% [markdown]
# ## Οπτικοποιεί τη multi-step πρόβλεψη του μοντέλου για ένα συγκεκριμένο δείγμα εισόδου. Σχεδιάζει τόσο τις προβλέψεις όσο και τις πραγματικές τιμές για τα επόμενα 800 βήματα (t+1 έως t+800).

# %%
# Επίλεξε το δείγμα που θέλεις να προβάλλεις (π.χ. δείγμα #10)
sample_index =34000

# Δημιουργία του διαγράμματος
plt.figure(figsize=(10, 5))

# Προβλέψεις για t+1 έως t+10
plt.plot(
    predictions_test[sample_index],
    label='Πρόβλεψη (t+1 έως t+10)',
    linestyle='--',
    #marker='o',
    #lw=5,
    color='red'
)

# Πραγματικές τιμές για t+1 έως t+10
plt.plot(
    test_set[sample_index],
    label='Πραγματικές τιμές',
    linestyle='-',
    #marker='x',
    #lw=5,
    color='blue'
)

# Επεξηγήσεις και styling
plt.title(f'Πρόβλεψη 10 βημάτων για το training δείγμα #{sample_index}', fontsize=14)
plt.xlabel('Βήμα στο μέλλον (1 = t+1, ..., 10 = t+10)', fontsize=12)
plt.ylabel('Τιμή', fontsize=12)
plt.xticks(ticks=range(10), labels=[f't+{i+1}' for i in range(10)])
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

#plt.rcParams['lines.linewidth'] = 0.5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[172], line 9
#       5 plt.figure(figsize=(10, 5))
#       7 # Προβλέψεις για t+1 έως t+10
#       8 plt.plot(
# ----> 9     predictions_test[sample_index],
#      10     label='Πρόβλεψη (t+1 έως t+10)',
#      11     linestyle='--',
#      12     #marker='o',
#      13     #lw=5,
#      14     color='red'
#      15 )
#      17 # Πραγματικές τιμές για t+1 έως t+10
#      18 plt.plot(
#      19     test_set[sample_index],
#      20     label='Πραγματικές τιμές',
#    (...)     24     color='blue'
#      25 )
#
# IndexError: index 34000 is out of bounds for axis 0 with size 9830

# %%
pe=[]
steps = []
forecast_horizon=800
for i in range(forecast_horizon):
    x=float(predictions_test[9000][i])
    y=float(y_test[9000][i])
    percent_error=abs((x-y)/y)
    if percent_error > 0.05:
        print(f"in {i} the deviation is more than 5% and exactlly {percent_error}")
        pe.append(percent_error)
        steps.append(i)

# %%
plt.figure(figsize=(10,4))
plt.plot(steps, pe, label='Percent Error')


plt.xlabel('Βήμα στο μέλλον')
plt.ylabel('Percent Error')
plt.title('Percent Error ανά forecast step')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Testing Set

# %%
# Παράγουμε τις προβλέψεις του ESN για τα νέα, αθέατα δεδομένα του test set
predictions_test = esn.predict(y_train)

# %%
# Διάλεξε δείγμα από το test set (π.χ. το 10ο δείγμα μέσα στο test set)
sample_index =4000


# Δημιουργία γραφήματος
plt.figure(figsize=(10, 5))

# Προβλέψεις (10 βήματα στο μέλλον)
plt.plot(
    predictions_test[sample_index],
    label='Πρόβλεψη (t+1 έως t+10)',
    linestyle='--',
    #marker='o',
    linewidth=1,
    color='red'
)

# Πραγματικές τιμές (ground truth)
plt.plot(
    y_test[sample_index],
    label='Πραγματικές τιμές',
    linestyle='-',
    #marker='x',
    linewidth=1,
    color='blue'
)

# Διαμόρφωση και επεξηγήσεις
plt.title(f'Πρόβλεψη 10 βημάτων για το test δείγμα #{sample_index}', fontsize=14)
plt.xlabel('Βήμα στο μέλλον (t+1 έως t+10)', fontsize=12)
plt.ylabel('Τιμή', fontsize=12)
plt.xticks(ticks=range(10), labels=[f't+{i+1}' for i in range(10)])
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Εδώ εντοπίζουμε απο ποιό σημείο και μετα η απόκλιση απο την πραγματική τιμή ξεπερνάει το 5%

# %%
pe=[]
steps = []
forecast_horizon=800
for i in range(forecast_horizon):
    x=float(predictions_test[9000][i])
    y=float(y_test[9000][i])
    percent_error=abs((x-y)/y)
    if percent_error > 0.05:
        print(f"in {i} the deviation is more than 5% and exactlly {percent_error}")
        pe.append(percent_error)
        steps.append(i)

# %%
plt.figure(figsize=(10,4))
plt.plot(steps, pe, label='Percent Error')


plt.xlabel('Βήμα στο μέλλον')
plt.ylabel('Percent Error')
plt.title('Percent Error ανά forecast step')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
